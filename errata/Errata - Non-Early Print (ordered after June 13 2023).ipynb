# %% [markdown]
# # Errata
#
# (Books ordered after ~12:00 PM GMT on June 13, 2023)

# %% [markdown]
# ## Chapter 02
#
#
# **Page 22**
#
#
# In the book (p. 22) we say:
# _______________________________________________________________
#
# *(...) the probability of buying book A, given we bought book B, is 63.8%. This indicates a
# positive relationship between both variables (if there was no association between them, we would
# expect the result to be <font color='red'>**50%**</font>)*
#
#
# This is <font color='red'>**incorrect**</font>.
#
# _______________________________________________________________
#
# The <font color='green'>**correct**</font> statement should be:
#
# *(...) the probability of buying book A, given we bought book B, is 63.8%. This indicates a
# positive relationship between both variables (if there was no association between them, we would
# expect the result to be <font color='green'>**39%**</font>)*
# _______________________________________________________________
#
#
# *Thanks for David for spotting this mistake.*

# %% [markdown]
# ## Chapter 06
#
#
# ### Instrumental variables
#
# **Page 121**
#
# In the book (p. 121) one of the formulas for regression models is <font color='red'>**incorrect**</font>.
#
# The book says:
#
# _________
#
#
# *To calculate the causal effect of X on Y in a linear case, all we need to do is fit two linear regression
# models and compute the ratio of their coefficients!*
#
# *The two models are as follows:*
#
# *• Y ~ Z*
#
# <font color='red'>*• Y ~ X*</font>
#
# _____________
#
#
# The <font color='green'>**correct**</font> formulas should be:
#
# _____________
#
# *The two models are as follows:*
#
# *• Y ~ Z*
#
# <font color='green'>*• X ~ Z*</font>
#
# __________________
#
#
# The **code example** below uses the <font color='green'>**correct formulas**</font>.

# %% [markdown]
# ## Chapter 13
#
#
# **Page 343** (point 3)
#
#
# In the book (p. 343) in point **3.** we say:
#
# _______________________________________________________________
#
# 3. *We remove the edges between <font color='red'>**P and Q**</font>, and Q and S, as P ⫫ Q | R and Q ⫫ S | R (C).*
#
#
# This is <font color='red'>**incorrect**</font>.
#
# _______________________________________________________________
#
# The <font color='green'>**correct**</font> statement should be:
#
# 3. *We remove the edges between <font color='green'>**P and S**</font>, and Q and S, as P ⫫ Q | R and Q ⫫ S | R (C).*
#
# _______________________________________________________________
#
#
# *Thanks for Miguel for spotting this mistake.*
#
# ______________________________________________________
# <br><br>
#
# **Page 343** (point 4)
#
# In the book (p. 343) in point **4.** we say:
# _______________________________________________________________
#
# 4. *We orient the edges <font color='red'>**P -> R <- S**</font> because R is a collider between <font color='red'>**P and S**</font> (D).*
#
#
# This is <font color='red'>**incorrect**</font>.
#
# _______________________________________________________________
#
# The <font color='green'>**correct**</font> statement should be:
#
# 4. *We orient the edges <font color='green'>**P -> R <- Q**</font> because R is a collider between <font color='green'>**P and Q**</font> (D).*
#
# _______________________________________________________________
#
#
# *Thanks for Takashi for spotting this mistake.*

# %% [markdown]
# ## Chapter 14
#
# **Page 391** (bullet point 1)
#
#
# In the book (p. 391) in the first bullet point we say:
#
# _______________________________________________________________
#
# *- <font color='red'>**X**</font> is not an ancestor of <font color='red'>**Y**</font> - there might be...*
#
#
# This is <font color='red'>**incorrect**</font>.
#
# _______________________________________________________________
#
# The <font color='green'>**correct**</font> statement should be:
#
# *- <font color='green'>**Y**</font> is not an ancestor of <font color='green'>**X**</font> - there might be...*
# _______________________________________________________________
